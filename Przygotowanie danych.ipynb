# %%
import os
import pandas as pd

# Define root directories for `o_d_` and `k_d_t_` files
opad_root_directory = "/lakehouse/default/Files/dobowe/opad"
klimat_root_directory = "/lakehouse/default/Files/dobowe/klimat"
output_directory = "/lakehouse/default/Files/Data"

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Output file paths
o_d_output_file = os.path.join(output_directory, "combined_o_d_data.csv")
k_d_t_output_file = os.path.join(output_directory, "combined_k_d_t_data.csv")

# Headers for `o_d_` and `k_d_t_` files based on your description
o_d_columns = [
    "Kod_stacji",
    "Nazwa_stacji",
    "Rok",
    "Miesiac",
    "Dzien",
    "Suma_dobowa_opadow",
    "Status_pomiaru_SMDB",
    "Rodzaj_opadu_S_W",
    "Wysokosc_pokrywy_snieznej_cm",
    "Status_pomiaru_PKSN",
    "Wysokosc_swiezospalego_sniegu_cm",
    "Status_pomiaru_HSS",
    "Gatunek_sniegu_kod",
    "Status_pomiaru_GATS",
    "Rodzaj_pokrywy_snieznej_kod",
    "Status_pomiaru_RPSN",
]

k_d_t_columns = [
    "Kod_stacji",
    "Nazwa_stacji",
    "Rok",
    "Miesiac",
    "Dzien",
    "Srednia_dobowa_temperatura_C",
    "Status_pomiaru_TEMP",
    "Srednia_dobowa_wilgotnosc_wzgledna_proc",
    "Status_pomiaru_WLGS",
    "Srednia_dobowa_predkosc_wiatru_ms",
    "Status_pomiaru_FWS",
    "Srednie_dobowe_zachmurzenie_ogolne_oktanty",
    "Status_pomiaru_NOS",
]

# Helper function to load a CSV file with fallback encodings
def load_csv_with_fallback(file_path, columns):
    encodings = ["utf-8", "windows-1250"]
    for encoding in encodings:
        try:
            df = pd.read_csv(file_path, encoding=encoding, header=None, sep=",")
            df.columns = columns  # Assign custom headers
            return df
        except Exception:
            continue
    raise ValueError(f"Failed to load file: {file_path} with all tested encodings.")

# Function to process files and write to a single output file
def process_and_append_files(root_directory, file_prefix, output_file, columns):
    # Write headers explicitly at the beginning
    with open(output_file, mode="w", encoding="utf-8", newline="") as f:
        pd.DataFrame(columns=columns).to_csv(f, index=False, sep=",")
    
    for subdir, _, files in os.walk(root_directory):
        for file_name in files:
            if file_name.startswith(file_prefix) and file_name.endswith(".csv"):
                file_path = os.path.join(subdir, file_name)
                try:
                    df = load_csv_with_fallback(file_path, columns)
                    # Append to the output file
                    df.to_csv(output_file, mode="a", index=False, header=False, sep=",")
                    print(f"Processed and appended: {file_name}")
                except Exception as e:
                    print(f"Error processing {file_name}: {e}")

# Process and append `o_d_` files
print("Processing o_d_ files...")
process_and_append_files(opad_root_directory, "o_d_", o_d_output_file, o_d_columns)

# Process and append `k_d_t_` files
print("Processing k_d_t_ files...")
process_and_append_files(klimat_root_directory, "k_d_t_", k_d_t_output_file, k_d_t_columns)

print("Data processing completed.")
# Out:
# StatementMeta(, e622cbff-ed2b-4ad4-9548-f7cd749c88f0, 3, Finished, Available, Finished)
# Processing o_d_ files...
# Processed and appended: o_d_01_2001.csv
# Processed and appended: o_d_02_2001.csv
# Processed and appended: o_d_03_2001.csv
# Processed and appended: o_d_04_2001.csv
# Processed and appended: o_d_05_2001.csv
# Processed and appended: o_d_06_2001.csv
# Processed and appended: o_d_07_2001.csv
# Processed and appended: o_d_08_2001.csv
# Processed and appended: o_d_09_2001.csv
# Processed and appended: o_d_10_2001.csv
# Processed and appended: o_d_11_2001.csv
# Processed and appended: o_d_12_2001.csv
# Processed and appended: o_d_01_2002.csv
# Processed and appended: o_d_02_2002.csv
# Processed and appended: o_d_03_2002.csv
# Processed and appended: o_d_04_2002.csv
# Processed and appended: o_d_05_2002.csv
# Processed and appended: o_d_06_2002.csv
# Processed and appended: o_d_07_2002.csv
# Processed and appended: o_d_08_2002.csv
# Processed and appended: o_d_09_2002.csv
# Processed and appended: o_d_10_2002.csv
# Processed and appended: o_d_11_2002.csv
# Processed and appended: o_d_12_2002.csv
# Processed and appended: o_d_01_2003.csv
# Processed and appended: o_d_02_2003.csv
# Processed and appended: o_d_03_2003.csv
# Processed and appended: o_d_04_2003.csv
# Processed and appended: o_d_05_2003.csv
# Processed and appended: o_d_06_2003.csv
# Processed and appended: o_d_07_2003.csv
# Processed and appended: o_d_08_2003.csv
# Processed and appended: o_d_09_2003.csv
# Processed and appended: o_d_10_2003.csv
# Processed and appended: o_d_11_2003.csv
# Processed and appended: o_d_12_2003.csv
# Processed and appended: o_d_01_2004.csv
# Processed and appended: o_d_02_2004.csv
# Processed and appended: o_d_03_2004.csv
# Processed and appended: o_d_04_2004.csv
# Processed and appended: o_d_05_2004.csv
# Processed and appended: o_d_06_2004.csv
# Processed and appended: o_d_07_2004.csv
# Processed and appended: o_d_08_2004.csv
# Processed and appended: o_d_09_2004.csv
# Processed and appended: o_d_10_2004.csv
# Processed and appended: o_d_11_2004.csv
# Processed and appended: o_d_12_2004.csv
# Processed and appended: o_d_01_2005.csv
# Processed and appended: o_d_02_2005.csv
# Processed and appended: o_d_03_2005.csv
# Processed and appended: o_d_04_2005.csv
# Processed and appended: o_d_05_2005.csv
# Processed and appended: o_d_06_2005.csv
# Processed and appended: o_d_07_2005.csv
# Processed and appended: o_d_08_2005.csv
# Processed and appended: o_d_09_2005.csv
# Processed and appended: o_d_10_2005.csv
# Processed and appended: o_d_11_2005.csv
# Processed and appended: o_d_12_2005.csv
# Processed and appended: o_d_01_2006.csv
# Processed and appended: o_d_02_2006.csv
# Processed and appended: o_d_03_2006.csv
# Processed and appended: o_d_04_2006.csv
# Processed and appended: o_d_05_2006.csv
# Processed and appended: o_d_06_2006.csv
# Processed and appended: o_d_07_2006.csv
# Processed and appended: o_d_08_2006.csv
# Processed and appended: o_d_09_2006.csv
# Processed and appended: o_d_10_2006.csv
# Processed and appended: o_d_11_2006.csv
# Processed and appended: o_d_12_2006.csv
# Processed and appended: o_d_01_2007.csv
# Processed and appended: o_d_02_2007.csv
# Processed and appended: o_d_03_2007.csv
# Processed and appended: o_d_04_2007.csv
# Processed and appended: o_d_05_2007.csv
# Processed and appended: o_d_06_2007.csv
# Processed and appended: o_d_07_2007.csv
# Processed and appended: o_d_08_2007.csv
# Processed and appended: o_d_09_2007.csv
# Processed and appended: o_d_10_2007.csv
# Processed and appended: o_d_11_2007.csv
# Processed and appended: o_d_12_2007.csv
# Processed and appended: o_d_01_2008.csv
# Processed and appended: o_d_02_2008.csv
# Processed and appended: o_d_03_2008.csv
# Processed and appended: o_d_04_2008.csv
# Processed and appended: o_d_05_2008.csv
# Processed and appended: o_d_06_2008.csv
# Processed and appended: o_d_07_2008.csv
# Processed and appended: o_d_08_2008.csv
# Processed and appended: o_d_09_2008.csv
# Processed and appended: o_d_10_2008.csv
# Processed and appended: o_d_11_2008.csv
# Processed and appended: o_d_12_2008.csv
# Processed and appended: o_d_01_2009.csv
# Processed and appended: o_d_02_2009.csv
# Processed and appended: o_d_03_2009.csv
# Processed and appended: o_d_04_2009.csv
# Processed and appended: o_d_05_2009.csv
# Processed and appended: o_d_06_2009.csv
# Processed and appended: o_d_07_2009.csv
# Processed and appended: o_d_08_2009.csv
# Processed and appended: o_d_09_2009.csv
# Processed and appended: o_d_10_2009.csv
# Processed and appended: o_d_11_2009.csv
# Processed and appended: o_d_12_2009.csv
# Processed and appended: o_d_01_2010.csv
# Processed and appended: o_d_02_2010.csv
# Processed and appended: o_d_03_2010.csv
# Processed and appended: o_d_04_2010.csv
# Processed and appended: o_d_05_2010.csv
# Processed and appended: o_d_06_2010.csv
# Processed and appended: o_d_07_2010.csv
# Processed and appended: o_d_08_2010.csv
# Processed and appended: o_d_09_2010.csv
# Processed and appended: o_d_10_2010.csv
# Processed and appended: o_d_11_2010.csv
# Processed and appended: o_d_12_2010.csv
# Processed and appended: o_d_01_2011.csv
# Processed and appended: o_d_02_2011.csv
# Processed and appended: o_d_03_2011.csv
# Processed and appended: o_d_04_2011.csv
# Processed and appended: o_d_05_2011.csv
# Processed and appended: o_d_06_2011.csv
# Processed and appended: o_d_07_2011.csv
# Processed and appended: o_d_08_2011.csv
# Processed and appended: o_d_09_2011.csv
# Processed and appended: o_d_10_2011.csv
# Processed and appended: o_d_11_2011.csv
# Processed and appended: o_d_12_2011.csv
# Processed and appended: o_d_01_2012.csv
# Processed and appended: o_d_02_2012.csv
# Processed and appended: o_d_03_2012.csv
# Processed and appended: o_d_04_2012.csv
# Processed and appended: o_d_05_2012.csv
# Processed and appended: o_d_06_2012.csv
# Processed and appended: o_d_07_2012.csv
# Processed and appended: o_d_08_2012.csv
# Processed and appended: o_d_09_2012.csv
# Processed and appended: o_d_10_2012.csv
# Processed and appended: o_d_11_2012.csv
# Processed and appended: o_d_12_2012.csv
# Processed and appended: o_d_01_2013.csv
# Processed and appended: o_d_02_2013.csv
# Processed and appended: o_d_03_2013.csv
# Processed and appended: o_d_04_2013.csv
# Processed and appended: o_d_05_2013.csv
# Processed and appended: o_d_06_2013.csv
# Processed and appended: o_d_07_2013.csv
# Processed and appended: o_d_08_2013.csv
# Processed and appended: o_d_09_2013.csv
# Processed and appended: o_d_10_2013.csv
# Processed and appended: o_d_11_2013.csv
# Processed and appended: o_d_12_2013.csv
# Processed and appended: o_d_01_2014.csv
# Processed and appended: o_d_02_2014.csv
# Processed and appended: o_d_03_2014.csv
# Processed and appended: o_d_04_2014.csv
# Processed and appended: o_d_05_2014.csv
# Processed and appended: o_d_06_2014.csv
# Processed and appended: o_d_07_2014.csv
# Processed and appended: o_d_08_2014.csv
# Processed and appended: o_d_09_2014.csv
# Processed and appended: o_d_10_2014.csv
# Processed and appended: o_d_11_2014.csv
# Processed and appended: o_d_12_2014.csv
# Processed and appended: o_d_01_2015.csv
# Processed and appended: o_d_02_2015.csv
# Processed and appended: o_d_03_2015.csv
# Processed and appended: o_d_04_2015.csv
# Processed and appended: o_d_05_2015.csv
# Processed and appended: o_d_06_2015.csv
# Processed and appended: o_d_07_2015.csv
# Processed and appended: o_d_08_2015.csv
# Processed and appended: o_d_09_2015.csv
# Processed and appended: o_d_10_2015.csv
# Processed and appended: o_d_11_2015.csv
# Processed and appended: o_d_12_2015.csv
# Processed and appended: o_d_01_2016.csv
# Processed and appended: o_d_02_2016.csv
# Processed and appended: o_d_03_2016.csv
# Processed and appended: o_d_04_2016.csv
# Processed and appended: o_d_05_2016.csv
# Processed and appended: o_d_06_2016.csv
# Processed and appended: o_d_07_2016.csv
# Processed and appended: o_d_08_2016.csv
# Processed and appended: o_d_09_2016.csv
# Processed and appended: o_d_10_2016.csv
# Processed and appended: o_d_11_2016.csv
# Processed and appended: o_d_12_2016.csv
# Processed and appended: o_d_01_2017.csv
# Processed and appended: o_d_02_2017.csv
# Processed and appended: o_d_03_2017.csv
# Processed and appended: o_d_04_2017.csv
# Processed and appended: o_d_05_2017.csv
# Processed and appended: o_d_06_2017.csv
# Processed and appended: o_d_07_2017.csv
# Processed and appended: o_d_08_2017.csv
# Processed and appended: o_d_09_2017.csv
# Processed and appended: o_d_10_2017.csv
# Processed and appended: o_d_11_2017.csv
# Processed and appended: o_d_12_2017.csv
# Processed and appended: o_d_01_2018.csv
# Processed and appended: o_d_02_2018.csv
# Processed and appended: o_d_03_2018.csv
# Processed and appended: o_d_04_2018.csv
# Processed and appended: o_d_05_2018.csv
# Processed and appended: o_d_06_2018.csv
# Processed and appended: o_d_07_2018.csv
# Processed and appended: o_d_08_2018.csv
# Processed and appended: o_d_09_2018.csv
# Processed and appended: o_d_10_2018.csv
# Processed and appended: o_d_11_2018.csv
# Processed and appended: o_d_12_2018.csv
# Processed and appended: o_d_01_2019.csv
# Processed and appended: o_d_02_2019.csv
# Processed and appended: o_d_03_2019.csv
# Processed and appended: o_d_04_2019.csv
# Processed and appended: o_d_05_2019.csv
# Processed and appended: o_d_06_2019.csv
# Processed and appended: o_d_07_2019.csv
# Processed and appended: o_d_08_2019.csv
# Processed and appended: o_d_09_2019.csv
# Processed and appended: o_d_10_2019.csv
# Processed and appended: o_d_11_2019.csv
# Processed and appended: o_d_12_2019.csv
# Processed and appended: o_d_01_2020.csv
# Processed and appended: o_d_02_2020.csv
# Processed and appended: o_d_03_2020.csv
# Processed and appended: o_d_04_2020.csv
# Processed and appended: o_d_05_2020.csv
# Processed and appended: o_d_06_2020.csv
# Processed and appended: o_d_07_2020.csv
# Processed and appended: o_d_08_2020.csv
# Processed and appended: o_d_09_2020.csv
# Processed and appended: o_d_10_2020.csv
# Processed and appended: o_d_11_2020.csv
# Processed and appended: o_d_12_2020.csv
# Processed and appended: o_d_01_2021.csv
# Processed and appended: o_d_02_2021.csv
# Processed and appended: o_d_03_2021.csv
# Processed and appended: o_d_04_2021.csv
# Processed and appended: o_d_05_2021.csv
# Processed and appended: o_d_06_2021.csv
# Processed and appended: o_d_07_2021.csv
# Processed and appended: o_d_08_2021.csv
# Processed and appended: o_d_09_2021.csv
# Processed and appended: o_d_10_2021.csv
# Processed and appended: o_d_11_2021.csv
# Processed and appended: o_d_12_2021.csv
# Processed and appended: o_d_01_2022.csv
# Processed and appended: o_d_02_2022.csv
# Processed and appended: o_d_03_2022.csv
# Processed and appended: o_d_04_2022.csv
# Processed and appended: o_d_05_2022.csv
# Processed and appended: o_d_06_2022.csv
# Processed and appended: o_d_07_2022.csv
# Processed and appended: o_d_08_2022.csv
# Processed and appended: o_d_09_2022.csv
# Processed and appended: o_d_10_2022.csv
# Processed and appended: o_d_11_2022.csv
# Processed and appended: o_d_12_2022.csv
# Processed and appended: o_d_01_2023.csv
# Processed and appended: o_d_02_2023.csv
# Processed and appended: o_d_03_2023.csv
# Processed and appended: o_d_04_2023.csv
# Processed and appended: o_d_05_2023.csv
# Processed and appended: o_d_06_2023.csv
# Processed and appended: o_d_07_2023.csv
# Processed and appended: o_d_08_2023.csv
# Processed and appended: o_d_09_2023.csv
# Processed and appended: o_d_10_2023.csv
# Processed and appended: o_d_11_2023.csv
# Processed and appended: o_d_12_2023.csv
# Processed and appended: o_d_01_2024.csv
# Processed and appended: o_d_02_2024.csv
# Processed and appended: o_d_03_2024.csv
# Processed and appended: o_d_04_2024.csv
# Processed and appended: o_d_05_2024.csv
# Processed and appended: o_d_06_2024.csv
# Processed and appended: o_d_07_2024.csv
# Processed and appended: o_d_08_2024.csv
# Processed and appended: o_d_09_2024.csv
# Processed and appended: o_d_10_2024.csv
# Processing k_d_t_ files...
# Processed and appended: k_d_t_01_2001.csv
# Processed and appended: k_d_t_02_2001.csv
# Processed and appended: k_d_t_03_2001.csv
# Processed and appended: k_d_t_04_2001.csv
# Processed and appended: k_d_t_05_2001.csv
# Processed and appended: k_d_t_06_2001.csv
# Processed and appended: k_d_t_07_2001.csv
# Processed and appended: k_d_t_08_2001.csv
# Processed and appended: k_d_t_09_2001.csv
# Processed and appended: k_d_t_10_2001.csv
# Processed and appended: k_d_t_11_2001.csv
# Processed and appended: k_d_t_12_2001.csv
# Processed and appended: k_d_t_01_2002.csv
# Processed and appended: k_d_t_02_2002.csv
# Processed and appended: k_d_t_03_2002.csv
# Processed and appended: k_d_t_04_2002.csv
# Processed and appended: k_d_t_05_2002.csv
# Processed and appended: k_d_t_06_2002.csv
# Processed and appended: k_d_t_07_2002.csv
# Processed and appended: k_d_t_08_2002.csv
# Processed and appended: k_d_t_09_2002.csv
# Processed and appended: k_d_t_10_2002.csv
# Processed and appended: k_d_t_11_2002.csv
# Processed and appended: k_d_t_12_2002.csv
# Processed and appended: k_d_t_01_2003.csv
# Processed and appended: k_d_t_02_2003.csv
# Processed and appended: k_d_t_03_2003.csv
# Processed and appended: k_d_t_04_2003.csv
# Processed and appended: k_d_t_05_2003.csv
# Processed and appended: k_d_t_06_2003.csv
# Processed and appended: k_d_t_07_2003.csv
# Processed and appended: k_d_t_08_2003.csv
# Processed and appended: k_d_t_09_2003.csv
# Processed and appended: k_d_t_10_2003.csv
# Processed and appended: k_d_t_11_2003.csv
# Processed and appended: k_d_t_12_2003.csv
# Processed and appended: k_d_t_01_2004.csv
# Processed and appended: k_d_t_02_2004.csv
# Processed and appended: k_d_t_03_2004.csv
# Processed and appended: k_d_t_04_2004.csv
# Processed and appended: k_d_t_05_2004.csv
# Processed and appended: k_d_t_06_2004.csv
# Processed and appended: k_d_t_07_2004.csv
# Processed and appended: k_d_t_08_2004.csv
# Processed and appended: k_d_t_09_2004.csv
# Processed and appended: k_d_t_10_2004.csv
# Processed and appended: k_d_t_11_2004.csv
# Processed and appended: k_d_t_12_2004.csv
# Processed and appended: k_d_t_01_2005.csv
# Processed and appended: k_d_t_02_2005.csv
# Processed and appended: k_d_t_03_2005.csv
# Processed and appended: k_d_t_04_2005.csv
# Processed and appended: k_d_t_05_2005.csv
# Processed and appended: k_d_t_06_2005.csv
# Processed and appended: k_d_t_07_2005.csv
# Processed and appended: k_d_t_08_2005.csv
# Processed and appended: k_d_t_09_2005.csv
# Processed and appended: k_d_t_10_2005.csv
# Processed and appended: k_d_t_11_2005.csv
# Processed and appended: k_d_t_12_2005.csv
# Processed and appended: k_d_t_01_2006.csv
# Processed and appended: k_d_t_02_2006.csv
# Processed and appended: k_d_t_03_2006.csv
# Processed and appended: k_d_t_04_2006.csv
# Processed and appended: k_d_t_05_2006.csv
# Processed and appended: k_d_t_06_2006.csv
# Processed and appended: k_d_t_07_2006.csv
# Processed and appended: k_d_t_08_2006.csv
# Processed and appended: k_d_t_09_2006.csv
# Processed and appended: k_d_t_10_2006.csv
# Processed and appended: k_d_t_11_2006.csv
# Processed and appended: k_d_t_12_2006.csv
# Processed and appended: k_d_t_01_2007.csv
# Processed and appended: k_d_t_02_2007.csv
# Processed and appended: k_d_t_03_2007.csv
# Processed and appended: k_d_t_04_2007.csv
# Processed and appended: k_d_t_05_2007.csv
# Processed and appended: k_d_t_06_2007.csv
# Processed and appended: k_d_t_07_2007.csv
# Processed and appended: k_d_t_08_2007.csv
# Processed and appended: k_d_t_09_2007.csv
# Processed and appended: k_d_t_10_2007.csv
# Processed and appended: k_d_t_11_2007.csv
# Processed and appended: k_d_t_12_2007.csv
# Processed and appended: k_d_t_01_2008.csv
# Processed and appended: k_d_t_02_2008.csv
# Processed and appended: k_d_t_03_2008.csv
# Processed and appended: k_d_t_04_2008.csv
# Processed and appended: k_d_t_05_2008.csv
# Processed and appended: k_d_t_06_2008.csv
# Processed and appended: k_d_t_07_2008.csv
# Processed and appended: k_d_t_08_2008.csv
# Processed and appended: k_d_t_09_2008.csv
# Processed and appended: k_d_t_10_2008.csv
# Processed and appended: k_d_t_11_2008.csv
# Processed and appended: k_d_t_12_2008.csv
# Processed and appended: k_d_t_01_2009.csv
# Processed and appended: k_d_t_02_2009.csv
# Processed and appended: k_d_t_03_2009.csv
# Processed and appended: k_d_t_04_2009.csv
# Processed and appended: k_d_t_05_2009.csv
# Processed and appended: k_d_t_06_2009.csv
# Processed and appended: k_d_t_07_2009.csv
# Processed and appended: k_d_t_08_2009.csv
# Processed and appended: k_d_t_09_2009.csv
# Processed and appended: k_d_t_10_2009.csv
# Processed and appended: k_d_t_11_2009.csv
# Processed and appended: k_d_t_12_2009.csv
# Processed and appended: k_d_t_01_2010.csv
# Processed and appended: k_d_t_02_2010.csv
# Processed and appended: k_d_t_03_2010.csv
# Processed and appended: k_d_t_04_2010.csv
# Processed and appended: k_d_t_05_2010.csv
# Processed and appended: k_d_t_06_2010.csv
# Processed and appended: k_d_t_07_2010.csv
# Processed and appended: k_d_t_08_2010.csv
# Processed and appended: k_d_t_09_2010.csv
# Processed and appended: k_d_t_10_2010.csv
# Processed and appended: k_d_t_11_2010.csv
# Processed and appended: k_d_t_12_2010.csv
# Processed and appended: k_d_t_01_2011.csv
# Processed and appended: k_d_t_02_2011.csv
# Processed and appended: k_d_t_03_2011.csv
# Processed and appended: k_d_t_04_2011.csv
# Processed and appended: k_d_t_05_2011.csv
# Processed and appended: k_d_t_06_2011.csv
# Processed and appended: k_d_t_07_2011.csv
# Processed and appended: k_d_t_08_2011.csv
# Processed and appended: k_d_t_09_2011.csv
# Processed and appended: k_d_t_10_2011.csv
# Processed and appended: k_d_t_11_2011.csv
# Processed and appended: k_d_t_12_2011.csv
# Processed and appended: k_d_t_01_2012.csv
# Processed and appended: k_d_t_02_2012.csv
# Processed and appended: k_d_t_03_2012.csv
# Processed and appended: k_d_t_04_2012.csv
# Processed and appended: k_d_t_05_2012.csv
# Processed and appended: k_d_t_06_2012.csv
# Processed and appended: k_d_t_07_2012.csv
# Processed and appended: k_d_t_08_2012.csv
# Processed and appended: k_d_t_09_2012.csv
# Processed and appended: k_d_t_10_2012.csv
# Processed and appended: k_d_t_11_2012.csv
# Processed and appended: k_d_t_12_2012.csv
# Processed and appended: k_d_t_01_2013.csv
# Processed and appended: k_d_t_02_2013.csv
# Processed and appended: k_d_t_03_2013.csv
# Processed and appended: k_d_t_04_2013.csv
# Processed and appended: k_d_t_05_2013.csv
# Processed and appended: k_d_t_06_2013.csv
# Processed and appended: k_d_t_07_2013.csv
# Processed and appended: k_d_t_08_2013.csv
# Processed and appended: k_d_t_09_2013.csv
# Processed and appended: k_d_t_10_2013.csv
# Processed and appended: k_d_t_11_2013.csv
# Processed and appended: k_d_t_12_2013.csv
# Processed and appended: k_d_t_01_2014.csv
# Processed and appended: k_d_t_02_2014.csv
# Processed and appended: k_d_t_03_2014.csv
# Processed and appended: k_d_t_04_2014.csv
# Processed and appended: k_d_t_05_2014.csv
# Processed and appended: k_d_t_06_2014.csv
# Processed and appended: k_d_t_07_2014.csv
# Processed and appended: k_d_t_08_2014.csv
# Processed and appended: k_d_t_09_2014.csv
# Processed and appended: k_d_t_10_2014.csv
# Processed and appended: k_d_t_11_2014.csv
# Processed and appended: k_d_t_12_2014.csv
# Processed and appended: k_d_t_01_2015.csv
# Processed and appended: k_d_t_02_2015.csv
# Processed and appended: k_d_t_03_2015.csv
# Processed and appended: k_d_t_04_2015.csv
# Processed and appended: k_d_t_05_2015.csv
# Processed and appended: k_d_t_06_2015.csv
# Processed and appended: k_d_t_07_2015.csv
# Processed and appended: k_d_t_08_2015.csv
# Processed and appended: k_d_t_09_2015.csv
# Processed and appended: k_d_t_10_2015.csv
# Processed and appended: k_d_t_11_2015.csv
# Processed and appended: k_d_t_12_2015.csv
# Processed and appended: k_d_t_01_2016.csv
# Processed and appended: k_d_t_02_2016.csv
# Processed and appended: k_d_t_03_2016.csv
# Processed and appended: k_d_t_04_2016.csv
# Processed and appended: k_d_t_05_2016.csv
# Processed and appended: k_d_t_06_2016.csv
# Processed and appended: k_d_t_07_2016.csv
# Processed and appended: k_d_t_08_2016.csv
# Processed and appended: k_d_t_09_2016.csv
# Processed and appended: k_d_t_10_2016.csv
# Processed and appended: k_d_t_11_2016.csv
# Processed and appended: k_d_t_12_2016.csv
# Processed and appended: k_d_t_01_2017.csv
# Processed and appended: k_d_t_02_2017.csv
# Processed and appended: k_d_t_03_2017.csv
# Processed and appended: k_d_t_04_2017.csv
# Processed and appended: k_d_t_05_2017.csv
# Processed and appended: k_d_t_06_2017.csv
# Processed and appended: k_d_t_07_2017.csv
# Processed and appended: k_d_t_08_2017.csv
# Processed and appended: k_d_t_09_2017.csv
# Processed and appended: k_d_t_10_2017.csv
# Processed and appended: k_d_t_11_2017.csv
# Processed and appended: k_d_t_12_2017.csv
# Processed and appended: k_d_t_01_2018.csv
# Processed and appended: k_d_t_02_2018.csv
# Processed and appended: k_d_t_03_2018.csv
# Processed and appended: k_d_t_04_2018.csv
# Processed and appended: k_d_t_05_2018.csv
# Processed and appended: k_d_t_06_2018.csv
# Processed and appended: k_d_t_07_2018.csv
# Processed and appended: k_d_t_08_2018.csv
# Processed and appended: k_d_t_09_2018.csv
# Processed and appended: k_d_t_10_2018.csv
# Processed and appended: k_d_t_11_2018.csv
# Processed and appended: k_d_t_12_2018.csv
# Processed and appended: k_d_t_01_2019.csv
# Processed and appended: k_d_t_02_2019.csv
# Processed and appended: k_d_t_03_2019.csv
# Processed and appended: k_d_t_04_2019.csv
# Processed and appended: k_d_t_05_2019.csv
# Processed and appended: k_d_t_06_2019.csv
# Processed and appended: k_d_t_07_2019.csv
# Processed and appended: k_d_t_08_2019.csv
# Processed and appended: k_d_t_09_2019.csv
# Processed and appended: k_d_t_10_2019.csv
# Processed and appended: k_d_t_11_2019.csv
# Processed and appended: k_d_t_12_2019.csv
# Processed and appended: k_d_t_01_2020.csv
# Processed and appended: k_d_t_02_2020.csv
# Processed and appended: k_d_t_03_2020.csv
# Processed and appended: k_d_t_04_2020.csv
# Processed and appended: k_d_t_05_2020.csv
# Processed and appended: k_d_t_06_2020.csv
# Processed and appended: k_d_t_07_2020.csv
# Processed and appended: k_d_t_08_2020.csv
# Processed and appended: k_d_t_09_2020.csv
# Processed and appended: k_d_t_10_2020.csv
# Processed and appended: k_d_t_11_2020.csv
# Processed and appended: k_d_t_12_2020.csv
# Processed and appended: k_d_t_01_2021.csv
# Processed and appended: k_d_t_02_2021.csv
# Processed and appended: k_d_t_03_2021.csv
# Processed and appended: k_d_t_04_2021.csv
# Processed and appended: k_d_t_05_2021.csv
# Processed and appended: k_d_t_06_2021.csv
# Processed and appended: k_d_t_07_2021.csv
# Processed and appended: k_d_t_08_2021.csv
# Processed and appended: k_d_t_09_2021.csv
# Processed and appended: k_d_t_10_2021.csv
# Processed and appended: k_d_t_11_2021.csv
# Processed and appended: k_d_t_12_2021.csv
# Processed and appended: k_d_t_01_2022.csv
# Processed and appended: k_d_t_02_2022.csv
# Processed and appended: k_d_t_03_2022.csv
# Processed and appended: k_d_t_04_2022.csv
# Processed and appended: k_d_t_05_2022.csv
# Processed and appended: k_d_t_06_2022.csv
# Processed and appended: k_d_t_07_2022.csv
# Processed and appended: k_d_t_08_2022.csv
# Processed and appended: k_d_t_09_2022.csv
# Processed and appended: k_d_t_10_2022.csv
# Processed and appended: k_d_t_11_2022.csv
# Processed and appended: k_d_t_12_2022.csv
# Processed and appended: k_d_t_01_2023.csv
# Processed and appended: k_d_t_02_2023.csv
# Processed and appended: k_d_t_03_2023.csv
# Processed and appended: k_d_t_04_2023.csv
# Processed and appended: k_d_t_05_2023.csv
# Processed and appended: k_d_t_06_2023.csv
# Processed and appended: k_d_t_07_2023.csv
# Processed and appended: k_d_t_08_2023.csv
# Processed and appended: k_d_t_09_2023.csv
# Processed and appended: k_d_t_10_2023.csv
# Processed and appended: k_d_t_11_2023.csv
# Processed and appended: k_d_t_12_2023.csv
# Processed and appended: k_d_t_01_2024.csv
# Processed and appended: k_d_t_02_2024.csv
# Processed and appended: k_d_t_03_2024.csv
# Processed and appended: k_d_t_04_2024.csv
# Data processing completed.

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/Data/combined_k_d_t_data.csv"
df = pd.read_csv("/lakehouse/default/Files/Data/combined_k_d_t_data.csv")
display(df)
# Out:
# StatementMeta(, 670add35-abc3-4f89-a008-b2cdbea81c63, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 687451b4-5b6f-43ee-9ef4-038afa34576f)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("/lakehouse/default/Files/Data/combined_o_d_data.csv")

# Combine the columns into a single Date column
df['Date'] = pd.to_datetime(df['Rok'].astype(str) + '-' + df['Miesiac'].astype(str) + '-' + df['Dzien'].astype(str), errors='coerce')

# Drop the original columns
#df = df.drop(columns=['Rok', 'Miesiac', 'Dzien'])

# Save the updated dataframe to a new CSV file
df.to_csv('/lakehouse/default/Files/Data/combined_o_d_data_year.csv', index=False)
# Out:
# StatementMeta(, e622cbff-ed2b-4ad4-9548-f7cd749c88f0, 4, Finished, Available, Finished)
# /tmp/ipykernel_7477/3742968180.py:4: DtypeWarning: Columns (6,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/lakehouse/default/Files/Data/combined_o_d_data.csv")

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/Data/combined_o_d_data_year.csv"
df = pd.read_csv("/lakehouse/default/Files/Data/combined_o_d_data_year.csv")
display(df)
# Out:
# StatementMeta(, 670add35-abc3-4f89-a008-b2cdbea81c63, 7, Finished, Available, Finished)
# /tmp/ipykernel_7388/886680536.py:3: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/lakehouse/default/Files/Data/combined_o_d_data_year.csv")
# SynapseWidget(Synapse.DataFrame, a288c849-bc5a-431f-a388-5a2d135c5731)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("/lakehouse/default/Files/Data/combined_k_d_t_data.csv")

# Combine the columns into a single Date column
df['Date'] = pd.to_datetime(df['Rok'].astype(str) + '-' + df['Miesiac'].astype(str) + '-' + df['Dzien'].astype(str), errors='coerce')

# Drop the original columns
#df = df.drop(columns=['Rok', 'Miesiac', 'Dzien'])

# Save the updated dataframe to a new CSV file
df.to_csv('/lakehouse/default/Files/Data/combined_k_d_t_data_year.csv', index=False)
# Out:
# StatementMeta(, e622cbff-ed2b-4ad4-9548-f7cd749c88f0, 5, Finished, Available, Finished)
